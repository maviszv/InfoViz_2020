# %%
import pandas as pd

# %%
data = pd.read_excel("NOWHERE/NOWHERE_DATASET.xlsx")
data.head(20)
# Out:
#          Unnamed: 0  Unnamed: 1 Unnamed: 2    Unnamed: 3   Unnamed: 4  \
# 0               NaN         NaN  GEOGRAPHY           NaN          NaN
# 1    0= not related         NaN        NaN           NaN          NaN
# 2   1= very related         NaN     Europe  Nrth America  Middle East
# 3               NaN         NaN        NaN           NaN          NaN
# 4         CH-1995-1      1995.0          1           NaN          NaN
# 5         CH-1995-3      1995.0          1           NaN          NaN
# 6          E-1995-4      1995.0          1           NaN          NaN
# 7          E-1995-7      1995.0          1           NaN          NaN
# 8         E-1995-19      1995.0          1           NaN          NaN
# 9         E-1995-23      1995.0          1           NaN          NaN
# 10        E-1995-34      1995.0          1           NaN          NaN
# 11         I-1995-2      1995.0          1           NaN          NaN
# ...
